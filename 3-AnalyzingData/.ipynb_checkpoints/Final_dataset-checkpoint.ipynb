# %%
import pandas as pd

# %%
Final_data = pd.read_csv ("Man_data.csv")
Final_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 CropsM    TonnesM  US$1000M  TempChangeM  YearR  \
# 0           0             0  Maize  239548580  17247498        0.755      1
# 1           1             1  Maize  251853900  18385335        1.000      2
# 2           2             2  Maize  241376650  18827379        0.784      3
# 3           3             3  Maize  227766880  20726786        0.953      4
# 4           4             4  Maize  256229020  24341757        0.992      5
#
#    CropsRM   CropsSB  TonnesSB  ...   TonnesW  US$1000W  TempChangeW CropsRW  \
# 0        1  Soybeans  72223460  ...  62567284   5693623        0.755       3
# 1        1  Soybeans  75055290  ...  60639376   5821380        1.000       3
# 2        1  Soybeans  78671470  ...  52999932   5405993        0.784       3
# 3        1  Soybeans  75010030  ...  43703968   5725220        0.953       3
# 4        1  Soybeans  66782720  ...  63803256   7975407        0.992       3
#
# ...

# %%
Final_data.drop(['Unnamed: 0', 'Unnamed: 0.1', 'US$1000MSQ', 'US$1000SBSQ', 'US$1000WSQRT'], axis = 1, inplace=True)

# %%
Final_data.head()
# Out:
#   CropsM    TonnesM  US$1000M  TempChangeM  YearR  CropsRM   CropsSB  \
# 0  Maize  239548580  17247498        0.755      1        1  Soybeans
# 1  Maize  251853900  18385335        1.000      2        1  Soybeans
# 2  Maize  241376650  18827379        0.784      3        1  Soybeans
# 3  Maize  227766880  20726786        0.953      4        1  Soybeans
# 4  Maize  256229020  24341757        0.992      5        1  Soybeans
#
#    TonnesSB  US$1000SB  TempChangeSB  CropsRSB CropsW  Year   TonnesW  \
# 0  72223460   12277988         0.755         2  Wheat  1999  62567284
# 1  75055290   12534233         1.000         2  Wheat  2000  60639376
# 2  78671470   12666107         0.784         2  Wheat  2001  52999932
# 3  75010030   15227036         0.953         2  Wheat  2002  43703968
# 4  66782720   18031334         0.992         2  Wheat  2003  63803256
#
#    US$1000W  TempChangeW  CropsRW         US$1000MCUBE        US$1000SBCUBE  \
# ...

# %%
Final_data.to_csv('Final_data.csv')
