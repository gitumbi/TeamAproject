# %%
library(ggplot2)

# %%
Explore_dataset <- read.csv("C:/Users/Jess/Documents/School Work/DSO110C/crops_recode_dataset.csv")

# %%
### SCATTERPLOTS

# %%
## Scatterplot of temp change over years

# %%
d <- ggplot(Explore_dataset, aes(x = YearR, y = TempChange))
d + geom_point()
# Out:
# plot without title

# %%
d + geom_point() + geom_smooth(method=lm)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
## Scatterplots of Tonnes by TempChange

# %%
d <- ggplot(Explore_dataset, aes(x = TempChange, y = Tonnes))
d + geom_point()
# Out:
# plot without title

# %%
## Scatterplot Crop Value by TempChange

# %%
d <- ggplot(Explore_dataset, aes(x = TempChange, y =USD1000 ))
d + geom_point()
# Out:
# plot without title
