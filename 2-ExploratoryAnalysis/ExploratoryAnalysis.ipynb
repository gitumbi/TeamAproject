# %% [markdown]
# # Data Exploratory Analysis

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import seaborn as sns
# %matplotlib inline
import  statsmodels.api as sm
import statsmodels.stats.api as sms
from scipy.stats import boxcox

# %% [markdown]
# ## Importing Dataset

# %%
Data = pd.read_csv('../Data/CropsMergedDataR.csv')

# %%
Data.head()
# Out:
#    Crops  Year     Tonnes   USD1000  TempChange
# 0      1  1999  239548580  17247498       0.755
# 1      1  2000  251853900  18385335       1.000
# 2      1  2001  241376650  18827379       0.784
# 3      1  2002  227766880  20726786       0.953
# 4      1  2003  256229020  24341757       0.992

# %% [markdown]
# ## Correlation Matrix

# %%
Data.corr()
# Out:
#                    Crops          Year    Tonnes   USD1000    TempChange
# Crops       1.000000e+00 -3.100124e-14 -0.888102 -0.734551 -3.194985e-16
# Year       -3.100124e-14  1.000000e+00  0.159694  0.450929  3.434782e-01
# Tonnes     -8.881017e-01  1.596937e-01  1.000000  0.742385  6.486449e-02
# USD1000    -7.345509e-01  4.509294e-01  0.742385  1.000000  4.026271e-02
# TempChange -3.194985e-16  3.434782e-01  0.064864  0.040263  1.000000e+00

# %% [markdown]
# ## Scatter Matrix

# %%
pd.plotting.scatter_matrix(Data)
# Out:
# array([[<AxesSubplot:xlabel='Crops', ylabel='Crops'>,
#         <AxesSubplot:xlabel='Year', ylabel='Crops'>,
#         <AxesSubplot:xlabel='Tonnes', ylabel='Crops'>,
#         <AxesSubplot:xlabel='USD1000', ylabel='Crops'>,
#         <AxesSubplot:xlabel='TempChange', ylabel='Crops'>],
#        [<AxesSubplot:xlabel='Crops', ylabel='Year'>,
#         <AxesSubplot:xlabel='Year', ylabel='Year'>,
#         <AxesSubplot:xlabel='Tonnes', ylabel='Year'>,
#         <AxesSubplot:xlabel='USD1000', ylabel='Year'>,
#         <AxesSubplot:xlabel='TempChange', ylabel='Year'>],
#        [<AxesSubplot:xlabel='Crops', ylabel='Tonnes'>,
#         <AxesSubplot:xlabel='Year', ylabel='Tonnes'>,
#         <AxesSubplot:xlabel='Tonnes', ylabel='Tonnes'>,
#         <AxesSubplot:xlabel='USD1000', ylabel='Tonnes'>,
#         <AxesSubplot:xlabel='TempChange', ylabel='Tonnes'>],
#        [<AxesSubplot:xlabel='Crops', ylabel='USD1000'>,
#         <AxesSubplot:xlabel='Year', ylabel='USD1000'>,
# ...

# %%
sns.pairplot(Data)

# %% [markdown]
# ## Which of your variables are highly related to each other?

# %% [markdown]
# #### It looks like the variables that are highly and positively related  are the Tonnes and the USD1000, the year and the USD1000, the TempChange and the Year.

# %%
sns.heatmap(Data.corr(), annot=True)
# Out:
# <AxesSubplot:>
